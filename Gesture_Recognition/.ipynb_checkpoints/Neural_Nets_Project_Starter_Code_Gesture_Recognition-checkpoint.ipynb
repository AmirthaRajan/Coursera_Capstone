# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import time
import numpy as np
import os
import pandas as pd
import datetime
from skimage import io
from skimage.transform import resize
import random as rn
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dropout, Input, Dense, Flatten, TimeDistributed, BatchNormalization, Activation
from tensorflow.keras.layers import Conv2D, MaxPooling3D, Conv3D, MaxPooling2D, ZeroPadding3D, GlobalAveragePooling2D, AveragePooling3D, AveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import LSTM, GRU

from tensorflow.keras import optimizers
from tensorflow.keras.regularizers import l2

from tensorflow.keras.applications import mobilenet
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications import EfficientNetB0

#from scipy.misc import imread, imresize
# from tensorflow.compat.v1.keras.backend import get_session, set_session
# from tensorflow.keras.backend import clear_session
# from tensorflow.compat.v1 import ConfigProto, Session
# import gc

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
start = time.time()
np.random.seed(30)
rn.seed(30)
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('Project_data/val.csv').readlines())

# %%
pd.DataFrame([row.replace('\n','').split(';') for row in train_doc[0:5]],columns=['directory_name','Classification','Code'])
# Out:
#                               directory_name   Classification Code
# 0  WIN_20180926_16_54_08_Pro_Right_Swipe_new  Right_Swipe_new    1
# 1  WIN_20180925_18_02_58_Pro_Thumbs_Down_new  Thumbs_Down_new    3
# 2   WIN_20180925_17_33_08_Pro_Left_Swipe_new   Left_Swipe_new    0
# 3    WIN_20180925_17_51_17_Pro_Thumbs_Up_new    Thumbs_Up_new    4
# 4   WIN_20180926_17_17_35_Pro_Left_Swipe_new   Left_Swipe_new    0

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# # Remove the existing Train/Test Data folder in case its already present in colab workspace
# import shutil
# try:
#     shutil.rmtree('model_init_2021-08-0418_31_01.115729')
#     print('removed folder')
# except OSError as error:
#     print('folder not found')

# %%
x = 30
y = 120
z = 120
img_idx = np.arange(5,28,2)

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [1,3,5,7,9,11,13,15,16,18,20,21,23,25,27,29]#create a list of image numbers you want to use for a particular video
    x = 30
    y = 120
    z = 120

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = io.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    # Cropping the image by 10%
                    image = tf.image.central_crop(image,0.9)
                    
                    # resizing the image to 120x120
                    image = tf.image.resize(image,(y,z))
                    
                    batch_data[folder,idx,:,:,0:3] = image[:, :, 0:3]/255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        # left_out_data = len(folder_list) % batch_size
        left_out_data = len(t) - (num_batches * batch_size) # calculate the number of remaining data points
        if left_out_data > 0:
            batch_data = np.zeros((left_out_data,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((left_out_data,5)) # batch_labels is the one hot representation of the output
            for folder in range(left_out_data): # iterate over the left_out_data
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = io.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    # Cropping the image by 10%
                    image = tf.image.central_crop(image,0.9)
                    
                    # resizing the image to 120x120
                    image = tf.image.resize(image,(y,z))
                    
                    batch_data[folder,idx,:,:,0:3] = image[:, :, 0:3]/255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
# Initialize the model train parameters
curr_dt_time = datetime.datetime.now()
filtersize = (3,3,3)
dropout = 0.25
batch_size=30
input_shape = (30, 120, 120, 3)
nb_classes = 5

num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 30 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %%
# lets set the path for train and validation dataset
train_path = 'Project_data/train'
val_path = 'Project_data/val'

# generating the train and validation data using generators
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %% [markdown]
# ### Lets define Generic Methods

# %%
# method to visualize the model training and validation accuracy/loss history
def plot_graph(history):
    
    # define figure size for subplots with 2 cols and a row
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    
    # plot train and validation loss
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])

    # plot train and validation accuracy
    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    
    # add legends for the subplots
    axes[0].legend(['loss','val_loss'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %%
# Method to set optimizer , compile the model and fit and train the model on the dataset for the given bacth size and epochs
def train_model(model, batch_size, num_epochs, train_generator, val_generator, optimizer = optimizers.Adam(), checkpoint_flag = False):

    # print batch size and num of epochs
    print("batch_size :"+str(batch_size))
    print("# of epoch :"+str(num_epochs))
    
    # Validating the optimizer
    if optimizer == None:
        optimizer = optimizers.Adam()

    # Lets compile the model with metrics of categorical accuracy and loss function as categorical crossentropy
    model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])

    # generate the model checkpoint.
    LR = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.5, patience = 2, cooldown = 1, verbose = 1)
    ES = EarlyStopping(monitor='val_loss', verbose=1, mode='auto')
    if checkpoint_flag:
        # create a folder name based on timestamp for final model
        curr_dt_time = datetime.datetime.now()
        model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
        
        # create a directory
        if not os.path.exists(model_name):
            os.mkdir(model_name)
            
        # set the finalname for h5 file
        filepath = model_name + 'final_model.h5'
    
        # create checkpoint based on val_loss
        checkpoint = ModelCheckpoint(filepath, 
                                 monitor = 'val_loss', 
                                 verbose = 1, 
                                 save_best_only = True, 
                                 save_weights_only = False, 
                                 mode = 'auto', 
                                 save_freq = "epoch")
        callbacks_list = [checkpoint, ES, LR]
    else:
        callbacks_list = [ES, LR]

    # The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1


    # Let us now fit the model. This will start training the model and with the help of the 
    # checkpoints, you'll be able to save the model at the end of each epoch.
    model_history = model.fit(train_generator, steps_per_epoch = steps_per_epoch, epochs = num_epochs, verbose = 1, 
                callbacks = callbacks_list, validation_data = val_generator, 
                validation_steps = validation_steps, class_weight = None, workers = 1, initial_epoch = 0)


    return plot_graph(model_history)

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ## LETS BUILD A MODEL USING CONV2D + RNN

# %% [markdown]
# ### Model 1 - Conv2D_RNN_LSTM

# %%
# write your conv2D_RNN_model1 here
conv2D_RNN_model1 = Sequential()

conv2D_RNN_model1.add(TimeDistributed(Conv2D(16, (3, 3), activation='relu', padding='valid'), input_shape=input_shape))
conv2D_RNN_model1.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model1.add(TimeDistributed(AveragePooling2D((2, 2))))
conv2D_RNN_model1.add(TimeDistributed(Conv2D(16, (3,3), padding='valid', activation='relu')))
conv2D_RNN_model1.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model1.add(TimeDistributed(MaxPooling2D((2, 2))))
conv2D_RNN_model1.add(Dropout(0.05))

conv2D_RNN_model1.add(TimeDistributed(Conv2D(128, (3,3), padding='valid', activation='relu')))
conv2D_RNN_model1.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model1.add(TimeDistributed(MaxPooling2D((2, 2))))
conv2D_RNN_model1.add(TimeDistributed(Conv2D(128, (3,3), padding='same', activation='relu')))
conv2D_RNN_model1.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model1.add(TimeDistributed(AveragePooling2D((2, 2))))
conv2D_RNN_model1.add(Dropout(0.10))

conv2D_RNN_model1.add(TimeDistributed(Conv2D(512, (3,3), padding='same', activation='relu')))
conv2D_RNN_model1.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model1.add(TimeDistributed(MaxPooling2D((2, 2))))
conv2D_RNN_model1.add(TimeDistributed(Conv2D(512, (3,3), padding='same', activation='relu')))
conv2D_RNN_model1.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model1.add(Dropout(0.15))

conv2D_RNN_model1.add(TimeDistributed(Flatten()))

conv2D_RNN_model1.add(LSTM(1024, return_sequences=False))
conv2D_RNN_model1.add(Dropout(0.20))

conv2D_RNN_model1.add(Dense(nb_classes, activation='softmax'))
conv2D_RNN_model1.summary()

train_model(conv2D_RNN_model1, batch_size, 40, train_generator, val_generator, None)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_23 (TimeDis (None, 30, 118, 118, 16)  448
# _________________________________________________________________
# time_distributed_24 (TimeDis (None, 30, 118, 118, 16)  64
# _________________________________________________________________
# time_distributed_25 (TimeDis (None, 30, 59, 59, 16)    0
# _________________________________________________________________
# time_distributed_26 (TimeDis (None, 30, 57, 57, 16)    2320
# _________________________________________________________________
# time_distributed_27 (TimeDis (None, 30, 57, 57, 16)    64
# _________________________________________________________________
# time_distributed_28 (TimeDis (None, 30, 28, 28, 16)    0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30, 28, 28, 16)    0
# _________________________________________________________________
# time_distributed_29 (TimeDis (None, 30, 26, 26, 128)   18560
# _________________________________________________________________
# time_distributed_30 (TimeDis (None, 30, 26, 26, 128)   512
# _________________________________________________________________
# time_distributed_31 (TimeDis (None, 30, 13, 13, 128)   0
# _________________________________________________________________
# time_distributed_32 (TimeDis (None, 30, 13, 13, 128)   147584
# _________________________________________________________________
# time_distributed_33 (TimeDis (None, 30, 13, 13, 128)   512
# _________________________________________________________________
# time_distributed_34 (TimeDis (None, 30, 6, 6, 128)     0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30, 6, 6, 128)     0
# _________________________________________________________________
# time_distributed_35 (TimeDis (None, 30, 6, 6, 512)     590336
# _________________________________________________________________
# time_distributed_36 (TimeDis (None, 30, 6, 6, 512)     2048
# _________________________________________________________________
# time_distributed_37 (TimeDis (None, 30, 3, 3, 512)     0
# _________________________________________________________________
# time_distributed_38 (TimeDis (None, 30, 3, 3, 512)     2359808
# _________________________________________________________________
# time_distributed_39 (TimeDis (None, 30, 3, 3, 512)     2048
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30, 3, 3, 512)     0
# _________________________________________________________________
# time_distributed_40 (TimeDis (None, 30, 4608)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1024)              23072768
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 26,202,197
# Trainable params: 26,199,573
# Non-trainable params: 2,624
# _________________________________________________________________
# batch_size :30
# # of epoch :40
# Epoch 1/40
# 23/23 [==============================] - 59s 3s/step - loss: 2.2579 - categorical_accuracy: 0.2655 - val_loss: 1.7794 - val_categorical_accuracy: 0.2200
# Epoch 2/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.4633 - categorical_accuracy: 0.3183 - val_loss: 1.6256 - val_categorical_accuracy: 0.1600
# Epoch 3/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.3754 - categorical_accuracy: 0.3816 - val_loss: 1.6406 - val_categorical_accuracy: 0.2100
# Epoch 4/40
# 23/23 [==============================] - ETA: 0s - loss: 1.3341 - categorical_accuracy: 0.4027
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 [==============================] - 58s 3s/step - loss: 1.3341 - categorical_accuracy: 0.4027 - val_loss: 1.6336 - val_categorical_accuracy: 0.1500
# Epoch 5/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.2379 - categorical_accuracy: 0.4510 - val_loss: 1.6545 - val_categorical_accuracy: 0.2100
# Epoch 6/40
# 23/23 [==============================] - ETA: 0s - loss: 1.2205 - categorical_accuracy: 0.4585
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 [==============================] - 59s 3s/step - loss: 1.2205 - categorical_accuracy: 0.4585 - val_loss: 1.7313 - val_categorical_accuracy: 0.2200
# Epoch 7/40
# 23/23 [==============================] - 59s 3s/step - loss: 1.2114 - categorical_accuracy: 0.4525 - val_loss: 1.9934 - val_categorical_accuracy: 0.2200
# Epoch 8/40
# 23/23 [==============================] - ETA: 0s - loss: 1.1904 - categorical_accuracy: 0.4449
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 [==============================] - 58s 3s/step - loss: 1.1904 - categorical_accuracy: 0.4449 - val_loss: 1.9620 - val_categorical_accuracy: 0.2300
# Epoch 9/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.1858 - categorical_accuracy: 0.4540 - val_loss: 1.9767 - val_categorical_accuracy: 0.2100
# Epoch 10/40
# 23/23 [==============================] - ETA: 0s - loss: 1.1253 - categorical_accuracy: 0.5083
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 23/23 [==============================] - 59s 3s/step - loss: 1.1253 - categorical_accuracy: 0.5083 - val_loss: 2.0888 - val_categorical_accuracy: 0.2000
# Epoch 11/40
# 23/23 [==============================] - 58s 3s/step - loss: 1
40
# 23/23 [==============================] - 58s 3s/step - loss: 1.0880 - categorical_accuracy: 0.5324 - val_loss: 1.3887 - val_categorical_accuracy: 0.4000
# Epoch 30/40
# 23/23 [==============================] - 57s 2s/step - loss: 1.0759 - categorical_accuracy: 0.5339 - val_loss: 1.2951 - val_categorical_accuracy: 0.4500
# Epoch 31/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.0642 - categorical_accuracy: 0.5535 - val_loss: 1.4242 - val_categorical_accuracy: 0.3700
# Epoch 32/40
# 23/23 [==============================] - 56s 2s/step - loss: 1.0841 - categorical_accuracy: 0.5400 - val_loss: 1.2657 - val_categorical_accuracy: 0.4800
# Epoch 33/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.0483 - categorical_accuracy: 0.5716 - val_loss: 1.2528 - val_categorical_accuracy: 0.4600
# Epoch 34/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.0679 - categorical_accuracy: 0.5475 - val_loss: 1.2071 - val_categorical_accuracy: 0.4600
# Epoch 35/40
# 23/23 [==============================] - 57s 2s/step - loss: 1.0620 - categorical_accuracy: 0.5415 - val_loss: 1.2977 - val_categorical_accuracy: 0.4300
# Epoch 36/40
# 23/23 [==============================] - 56s 2s/step - loss: 1.0680 - categorical_accuracy: 0.5354 - val_loss: 1.2049 - val_categorical_accuracy: 0.4900
# Epoch 37/40
# 23/23 [==============================] - 57s 2s/step - loss: 1.0691 - categorical_accuracy: 0.5264 - val_loss: 1.1961 - val_categorical_accuracy: 0.4900
# Epoch 38/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.0532 - categorical_accuracy: 0.5566 - val_loss: 1.2203 - val_categorical_accuracy: 0.4600
# Epoch 39/40
# 23/23 [==============================] - 57s 2s/step - loss: 1.0663 - categorical_accuracy: 0.5370 - val_loss: 1.1558 - val_categorical_accuracy: 0.5100
# Epoch 40/40
# 23/23 [==============================] - 57s 2s/step - loss: 1.0684 - categorical_accuracy: 0.5400 - val_loss: 1.1350 - val_categorical_accuracy: 0.5400

# %% [markdown]
# ### Observation:
#
# Though the train and validation accuracy are the same, the accuracy is only 50% which is underfitting of data, hence lets reject this model

# %% [markdown]
# ### Model 2 - Conv2D_RNN_GRU

# %%
# write your conv2D_RNN_model2 here
conv2D_RNN_model2 = Sequential()

conv2D_RNN_model2.add(TimeDistributed(Conv2D(16, (3, 3), activation='relu', padding='valid'), input_shape=input_shape))
conv2D_RNN_model2.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model2.add(TimeDistributed(AveragePooling2D((2, 2))))
conv2D_RNN_model2.add(TimeDistributed(Conv2D(16, (3,3), padding='valid', activation='relu')))
conv2D_RNN_model2.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model2.add(TimeDistributed(MaxPooling2D((2, 2))))
conv2D_RNN_model2.add(Dropout(0.05))

conv2D_RNN_model2.add(TimeDistributed(Conv2D(128, (3,3), padding='valid', activation='relu')))
conv2D_RNN_model2.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model2.add(TimeDistributed(MaxPooling2D((2, 2))))
conv2D_RNN_model2.add(TimeDistributed(Conv2D(128, (3,3), padding='same', activation='relu')))
conv2D_RNN_model2.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model2.add(TimeDistributed(AveragePooling2D((2, 2))))
conv2D_RNN_model2.add(Dropout(0.10))

conv2D_RNN_model2.add(TimeDistributed(Conv2D(512, (3,3), padding='same', activation='relu')))
conv2D_RNN_model2.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model2.add(TimeDistributed(MaxPooling2D((2, 2))))
conv2D_RNN_model2.add(TimeDistributed(Conv2D(512, (3,3), padding='same', activation='relu')))
conv2D_RNN_model2.add(TimeDistributed(BatchNormalization()))
conv2D_RNN_model2.add(Dropout(0.15))

conv2D_RNN_model2.add(TimeDistributed(Flatten()))

conv2D_RNN_model2.add(GRU(1024, return_sequences=False))
conv2D_RNN_model2.add(Dropout(0.20))

conv2D_RNN_model2.add(Dense(nb_classes, activation='softmax'))
conv2D_RNN_model2.summary()

train_model(conv2D_RNN_model2, batch_size, 40, train_generator, val_generator, None)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_5 (TimeDist (None, 30, 118, 118, 16)  448
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 30, 118, 118, 16)  64
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 30, 59, 59, 16)    0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 30, 57, 57, 16)    2320
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 30, 57, 57, 16)    64
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 30, 28, 28, 16)    0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 28, 28, 16)    0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 30, 26, 26, 128)   18560
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 30, 26, 26, 128)   512
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 30, 13, 13, 128)   0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 30, 13, 13, 128)   147584
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 30, 13, 13, 128)   512
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 30, 6, 6, 128)     0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30, 6, 6, 128)     0
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 30, 6, 6, 512)     590336
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 30, 6, 6, 512)     2048
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 30, 3, 3, 512)     0
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 30, 3, 3, 512)     2359808
# _________________________________________________________________
# time_distributed_21 (TimeDis (None, 30, 3, 3, 512)     2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30, 3, 3, 512)     0
# _________________________________________________________________
# time_distributed_22 (TimeDis (None, 30, 4608)          0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1024)              17307648
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 20,437,077
# Trainable params: 20,434,453
# Non-trainable params: 2,624
# _________________________________________________________________
# batch_size :30
# # of epoch :40
# Epoch 1/40
# 23/23 [==============================] - 68s 3s/step - loss: 4.1704 - categorical_accuracy: 0.2790 - val_loss: 3.6441 - val_categorical_accuracy: 0.1900
# Epoch 2/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.4747 - categorical_accuracy: 0.3741 - val_loss: 3.8792 - val_categorical_accuracy: 0.1600
# Epoch 3/40
# 23/23 [==============================] - ETA: 0s - loss: 1.4350 - categorical_accuracy: 0.3575
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 [==============================] - 58s 3s/step - loss: 1.4350 - categorical_accuracy: 0.3575 - val_loss: 4.1411 - val_categorical_accuracy: 0.1800
# Epoch 4/40
# 23/23 [==============================] - 56s 2s/step - loss: 1.3129 - categorical_accuracy: 0.4419 - val_loss: 3.4843 - val_categorical_accuracy: 0.1800
# Epoch 5/40
# 23/23 [==============================] - 58s 3s/step - loss: 1.1774 - categorical_accuracy: 0.4857 - val_loss: 3.8540 - val_categorical_accuracy: 0.1600
# Epoch 6/40
# 23/23 [==============================] - ETA: 0s - loss: 1.0997 - categorical_accuracy: 0.5430
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 [==============================] - 57s 2s/step - loss: 1.0997 - categorical_accuracy: 0.5430 - val_loss: 4.1667 - val_categorical_accuracy: 0.1500
# Epoch 7/40
# 23/23 [==============================] - 57s 2s/step - loss: 1.0174 - categorical_accuracy: 0.5762 - val_loss: 3.8371 - val_categorical_accuracy: 0.1400
# Epoch 8/40
# 23/23 [==============================] - 55s 2s/step - loss: 0.9088 - categorical_accuracy: 0.6290 - val_loss: 3.4259 - val_categorical_accuracy: 0.1600
# Epoch 9/40
# 23/23 [==============================] - 57s 2s/step - loss: 0.8737 - categorical_accuracy: 0.6772 - val_loss: 3.4296 - val_categorical_accuracy: 0.1600
# Epoch 10/40
# 23/23 [==============================] - ETA: 0s - loss: 0.7266 - categorical_accuracy: 0.7285
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 [==============================] - 58s 3s/step - loss: 0.7266 - categorical_accuracy: 0.7285 - val_loss: 7.1504 - val_categorical_accuracy: 0.1500
# Epoch 11/40
# 23/23 [==============================] - 57s 2s/step - loss: 0
40
# 23/23 [==============================] - 58s 3s/step - loss: 0.3297 - categorical_accuracy: 0.9095 - val_loss: 0.8048 - val_categorical_accuracy: 0.7300
# Epoch 31/40
# 23/23 [==============================] - 59s 3s/step - loss: 0.3482 - categorical_accuracy: 0.8869 - val_loss: 0.6391 - val_categorical_accuracy: 0.7900
# Epoch 32/40
# 23/23 [==============================] - 56s 2s/step - loss: 0.3643 - categorical_accuracy: 0.8778 - val_loss: 0.6567 - val_categorical_accuracy: 0.7700
# Epoch 33/40
# 23/23 [==============================] - 59s 3s/step - loss: 0.2962 - categorical_accuracy: 0.9080 - val_loss: 0.5855 - val_categorical_accuracy: 0.8400
# Epoch 34/40
# 23/23 [==============================] - 58s 3s/step - loss: 0.2919 - categorical_accuracy: 0.9201 - val_loss: 0.6862 - val_categorical_accuracy: 0.8000
# Epoch 35/40
# 23/23 [==============================] - ETA: 0s - loss: 0.2949 - categorical_accuracy: 0.9110
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 23/23 [==============================] - 58s 3s/step - loss: 0.2949 - categorical_accuracy: 0.9110 - val_loss: 0.6134 - val_categorical_accuracy: 0.8000
# Epoch 36/40
# 23/23 [==============================] - 57s 2s/step - loss: 0.3163 - categorical_accuracy: 0.9125 - val_loss: 0.5963 - val_categorical_accuracy: 0.8300
# Epoch 37/40
# 23/23 [==============================] - ETA: 0s - loss: 0.2721 - categorical_accuracy: 0.9125
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 23/23 [==============================] - 58s 3s/step - loss: 0.2721 - categorical_accuracy: 0.9125 - val_loss: 0.6013 - val_categorical_accuracy: 0.8000
# Epoch 38/40
# 23/23 [==============================] - 58s 3s/step - loss: 0.2554 - categorical_accuracy: 0.9276 - val_loss: 0.6955 - val_categorical_accuracy: 0.7700
# Epoch 39/40
# 23/23 [==============================] - 58s 3s/step - loss: 0.2766 - categorical_accuracy: 0.9246 - val_loss: 0.5318 - val_categorical_accuracy: 0.8300
# Epoch 40/40
# 23/23 [==============================] - 57s 2s/step - loss: 0.2493 - categorical_accuracy: 0.9382 - val_loss: 0.5929 - val_categorical_accuracy: 0.8400

# %% [markdown]
# ### Observation
#
# Using the above model and on switching from LSTM to GRU we couls see a good increase in training and validation accuracy. This is a farily decent model and can learn better than model1 in capturing information.

# %% [markdown]
# ### LETS SEE HOW THE CONV3D PERFROMS FOR THE GIVEN BATCH SIZE AND SEE IF IT THROWS OUT OF MEMORY ERROR

# %% [markdown]
# ### Experimental Conv3D model for a batch size of 30 and tested on 5 epochs

# %%
def con3D_model1_initialise():
        Conv3D_model1 = Sequential()

        Conv3D_model1.add(Conv3D(16, (3,3,3), padding='same',input_shape = input_shape))
        Conv3D_model1.add(Activation('relu'))
        Conv3D_model1.add(BatchNormalization())
        Conv3D_model1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        Conv3D_model1.add(Conv3D(32, (3,3,3), padding='same'))
        Conv3D_model1.add(Activation('relu'))
        Conv3D_model1.add(BatchNormalization())
        Conv3D_model1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        Conv3D_model1.add(Conv3D(64, (3,3,3), padding='same'))
        Conv3D_model1.add(Activation('relu'))
        Conv3D_model1.add(BatchNormalization())
        Conv3D_model1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        Conv3D_model1.add(Conv3D(128, (3,3,3), padding='same'))
        Conv3D_model1.add(Activation('relu'))
        Conv3D_model1.add(BatchNormalization())
        Conv3D_model1.add(MaxPooling3D(pool_size=(2, 2, 2)))

        Conv3D_model1.add(Flatten())
        Conv3D_model1.add(Dense(128, activation='relu'))
        Conv3D_model1.add(BatchNormalization())
        Conv3D_model1.add(Dropout(dropout))

        Conv3D_model1.add(Dense(64,activation='relu'))
        Conv3D_model1.add(BatchNormalization())
        Conv3D_model1.add(Dropout(dropout))

        Conv3D_model1.add(Dense(5,activation='softmax'))

        Conv3D_model1.summary()
        return Conv3D_model1
train_model(con3D_model1_initialise(), batch_size , 5, train_generator, val_generator, None)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 30, 120, 120, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 30, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 30, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 15, 60, 60, 32)    13856
# _________________________________________________________________
# activation_1 (Activation)    (None, 15, 60, 60, 32)    0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 15, 60, 60, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 7, 30, 30, 64)     55360
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 7, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 3, 15, 15, 128)    221312
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 3, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               802944
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,105,093
# Trainable params: 1,104,229
# Non-trainable params: 864
# _________________________________________________________________
# batch_size30
# Epoch 1/5
# 23/23 [==============================] - ETA: 0s - loss: 1.4972 - categorical_accuracy: 0.4434
# Epoch 00001: val_loss improved from inf to 1.54327, saving model to model_init_2021-08-0502_32_42.903577/final_model.h5
# 23/23 [==============================] - 58s 3s/step - loss: 1.4972 - categorical_accuracy: 0.4434 - val_loss: 1.5433 - val_categorical_accuracy: 0.3100
# Epoch 2/5
# 23/23 [==============================] - ETA: 0s - loss: 1.0087 - categorical_accuracy: 0.5988
# Epoch 00002: val_loss did not improve from 1.54327
# 23/23 [==============================] - 55s 2s/step - loss: 1.0087 - categorical_accuracy: 0.5988 - val_loss: 2.7197 - val_categorical_accuracy: 0.2700
# Epoch 3/5
# 23/23 [==============================] - ETA: 0s - loss: 0.8220 - categorical_accuracy: 0.6938
# Epoch 00003: val_loss did not improve from 1.54327
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 [==============================] - 56s 2s/step - loss: 0.8220 - categorical_accuracy: 0.6938 - val_loss: 5.0876 - val_categorical_accuracy: 0.1800
# Epoch 4/5
# 23/23 [==============================] - ETA: 0s - loss: 0.6134 - categorical_accuracy: 0.7722
# Epoch 00004: val_loss did not improve from 1.54327
# 23/23 [==============================] - 57s 2s/step - loss: 0.6134 - categorical_accuracy: 0.7722 - val_loss: 5.0334 - val_categorical_accuracy: 0.1500
# Epoch 5/5
# 23/23 [==============================] - ETA: 0s - loss: 0.4842 - categorical_accuracy: 0.8250
# Epoch 00005: val_loss did not improve from 1.54327
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 [==============================] - 56s 2s/step - loss: 0.4842 - categorical_accuracy: 0.8250 - val_loss: 4.5175 - val_categorical_accuracy: 0.1500

# %% [markdown]
# ### Experimentation outcome for batch size
#
# Based on different experimentational on the batch size, having a batch size of 30 utilized the GPU to its best performance without any Out of Memory issues, hence we stick to bacth size of 30

# %% [markdown]
# ### NOW LETS STICK TO THIS CONV3D MODEL AND INCREASE THE EPOCHS SIZE TO 20

# %% [markdown]
# ### Model 3 - Conv3D

# %%
train_model(con3D_model1_initialise(), batch_size , 20, train_generator, val_generator, None)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_4 (Conv3D)            (None, 30, 120, 120, 16)  1312
# _________________________________________________________________
# activation_4 (Activation)    (None, 30, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 30, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 15, 60, 60, 32)    13856
# _________________________________________________________________
# activation_5 (Activation)    (None, 15, 60, 60, 32)    0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 15, 60, 60, 32)    128
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 7, 30, 30, 64)     55360
# _________________________________________________________________
# activation_6 (Activation)    (None, 7, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 7, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 3, 15, 15, 128)    221312
# _________________________________________________________________
# activation_7 (Activation)    (None, 3, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 3, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               802944
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,105,093
# Trainable params: 1,104,229
# Non-trainable params: 864
# _________________________________________________________________
# batch_size30
# Epoch 1/20
# 23/23 [==============================] - ETA: 0s - loss: 1.3234 - categorical_accuracy: 0.5098
# Epoch 00001: val_loss improved from inf to 2.55291, saving model to model_init_2021-08-0502_37_31.307963/final_model.h5
# 23/23 [==============================] - 56s 2s/step - loss: 1.3234 - categorical_accuracy: 0.5098 - val_loss: 2.5529 - val_categorical_accuracy: 0.2100
# Epoch 2/20
# 23/23 [==============================] - ETA: 0s - loss: 0.7951 - categorical_accuracy: 0.7119
# Epoch 00002: val_loss did not improve from 2.55291
# 23/23 [==============================] - 56s 2s/step - loss: 0.7951 - categorical_accuracy: 0.7119 - val_loss: 4.3019 - val_categorical_accuracy: 0.2100
# Epoch 3/20
# 23/23 [==============================] - ETA: 0s - loss: 0.5691 - categorical_accuracy: 0.8115
# Epoch 00003: val_loss did not improve from 2.55291
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 [==============================] - 56s 2s/step - loss: 0.5691 - categorical_accuracy: 0.8115 - val_loss: 4.3216 - val_categorical_accuracy: 0.2500
# Epoch 4/20
# 23/23 [==============================] - ETA: 0s - loss: 0.4618 - categorical_accuracy: 0.8371
# Epoch 00004: val_loss did not improve from 2.55291
# 23/23 [==============================] - 57s 2s/step - loss: 0.4618 - categorical_accuracy: 0.8371 - val_loss: 5.8354 - val_categorical_accuracy: 0.1900
# Epoch 5/20
# 23/23 [==============================] - ETA: 0s - loss: 0.3614 - categorical_accuracy: 0.8688
# Epoch 00005: val_loss did not improve from 2.55291
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 [==============================] - 54s 2s/step - loss: 0.3614 - categorical_accuracy: 0.8688 - val_loss: 5.9666 - val_categorical_accuracy: 0.2300
# Epoch 6/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2795 - categorical_accuracy: 0.9140
# Epoch 00006: val_loss did not improve from 2.55291
# 23/23 [==============================] - 56s 2s/step - loss: 0.2795 - categorical_accuracy: 0.9140 - val_loss: 7.1844 - val_categorical_accuracy: 0.2100
# Epoch 7/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2582 - categorical_accuracy: 0.9231
# Epoch 00007: val_loss did not improve from 2.55291
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 [==============================] - 56s 2s/step - loss: 0.2582 - categorical_accuracy: 0.9231 - val_loss: 6.7266 - val_categorical_accuracy: 0.2500
# Epoch 8/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2411 - categorical_accuracy: 0.9382
# Epoch 00008: val_loss did not improve from 2.55291
# 23/23 [==============================] - 56s 2s/step - loss: 0.2411 - categorical_accuracy: 0.9382 - val_loss: 6.8887 - val_categorical_accuracy: 0.1900
# Epoch 9/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2031 - categorical_accuracy: 0.9442
# Epoch 00009: val_loss did not improve from 2.55291
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 23/23 [==============================] - 55s 2s/step - loss: 0.2031 - categorical_accuracy: 0.9442 - val_loss: 7.0627 - val_categorical_accuracy: 0.2200
# Epoch 10/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2157 - categorical_accuracy: 0.9351
# Epoch 00010: val_loss did not improve from 2.55291
# 23/23 [==============================] - 57s 2s/step - loss: 0.2157 - categorical_accuracy: 0.9351 - val_loss: 7.0623 - val_categorical_accuracy: 0.2100
# Epoch 11/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2014 - categorical_accuracy: 0.9563
# Epoch 00011: val_loss did not improve from 2.55291
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 23/23 [==============================] - 56s 2s/step - loss: 0.2014 - categorical_accuracy: 0.9563 - val_loss: 6.4409 - val_categorical_accuracy: 0.2200
# Epoch 12/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1915 - categorical_accuracy: 0.9487
# Epoch 00012: val_loss did not improve from 2.55291
# 23/23 [==============================] - 56s 2s/step - loss: 0.1915 - categorical_accuracy: 0.9487 - val_loss: 6.7481 - val_categorical_accuracy: 0.1900
# Epoch 13/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1870 - categorical_accuracy: 0.9457
# Epoch 00013: val_loss did not improve from 2.55291
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 23/23 [==============================] - 56s 2s/step - loss: 0.1870 - categorical_accuracy: 0.9457 - val_loss: 6.2053 - val_categorical_accuracy: 0.2100
# Epoch 14/20
# 23/23 [==============================] - ETA: 0s - loss: 0.2101 - categorical_accuracy: 0.9367
# Epoch 00014: val_loss did not improve from 2.55291
# 23/23 [==============================] - 56s 2s/step - loss: 0.2101 - categorical_accuracy: 0.9367 - val_loss: 6.1030 - val_categorical_accuracy: 0.2100
# Epoch 15/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1696 - categorical_accuracy: 0.9487
# Epoch 00015: val_loss did not improve from 2.55291
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 23/23 [==============================] - 57s 2s/step - loss: 0.1696 - categorical_accuracy: 0.9487 - val_loss: 5.5553 - val_categorical_accuracy: 0.2400
# Epoch 16/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1786 - categorical_accuracy: 0.9487
# Epoch 00016: val_loss did not improve from 2.55291
# 23/23 [==============================] - 57s 2s/step - loss: 0.1786 - categorical_accuracy: 0.9487 - val_loss: 5.0556 - val_categorical_accuracy: 0.2500
# Epoch 17/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1613 - categorical_accuracy: 0.9608
# Epoch 00017: val_loss did not improve from 2.55291
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 23/23 [==============================] - 55s 2s/step - loss: 0.1613 - categorical_accuracy: 0.9608 - val_loss: 4.7321 - val_categorical_accuracy: 0.2100
# Epoch 18/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1905 - categorical_accuracy: 0.9517
# Epoch 00018: val_loss did not improve from 2.55291
# 23/23 [==============================] - 56s 2s/step - loss: 0.1905 - categorical_accuracy: 0.9517 - val_loss: 4.0905 - val_categorical_accuracy: 0.2200
# Epoch 19/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1787 - categorical_accuracy: 0.9548
# Epoch 00019: val_loss did not improve from 2.55291
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 23/23 [==============================] - 56s 2s/step - loss: 0.1787 - categorical_accuracy: 0.9548 - val_loss: 3.5036 - val_categorical_accuracy: 0.2500
# Epoch 20/20
# 23/23 [==============================] - ETA: 0s - loss: 0.1645 - categorical_accuracy: 0.9578
# Epoch 00020: val_loss did not improve from 2.55291
# 23/23 [==============================] - 57s 2s/step - loss: 0.1645 - categorical_accuracy: 0.9578 - val_loss: 2.9197 - val_categorical_accuracy: 0.3500

# %% [markdown]
# ### Observation:
#
# As the paramteres of Conv2D_model2 is pretty high , we are trying out Conv3D model with an epoch of 20 and considering this as a base model for Conv3D. Its pretty obvious that it leads to overfiting as the training accuracy is way to more than validation accuracy.

# %% [markdown]
# ### INCREASE EPOCH TO 30

# %% [markdown]
# ### Model 4 - Conv3D

# %%
train_model(con3D_model1_initialise(), batch_size , 30, train_generator, val_generator, None)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 30, 120, 120, 16)  1312
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 30, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 15, 60, 60, 32)    13856
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 60, 60, 32)    0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 15, 60, 60, 32)    128
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 7, 30, 30, 64)     55360
# _________________________________________________________________
# activation_10 (Activation)   (None, 7, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 7, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 3, 15, 15, 128)    221312
# _________________________________________________________________
# activation_11 (Activation)   (None, 3, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 3, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               802944
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1
30
# 23/23 [==============================] - ETA: 0s - loss: 0.1776 - categorical_accuracy: 0.9563
# Epoch 00011: val_loss did not improve from 1.56328
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 23/23 [==============================] - 56s 2s/step - loss: 0.1776 - categorical_accuracy: 0.9563 - val_loss: 4.4382 - val_categorical_accuracy: 0.1600
# Epoch 12/30
# 23/23 [==============================] - ETA: 0s - loss: 0.2008 - categorical_accuracy: 0.9397
# Epoch 00012: val_loss did not improve from 1.56328
# 23/23 [==============================] - 56s 2s/step - loss: 0.2008 - categorical_accuracy: 0.9397 - val_loss: 4.4213 - val_categorical_accuracy: 0.2000
# Epoch 13/30
# 23/23 [==============================] - ETA: 0s - loss: 0.2158 - categorical_accuracy: 0.9336
# Epoch 00013: val_loss did not improve from 1.56328
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 23/23 [==============================] - 54s 2s/step - loss: 0.2158 - categorical_accuracy: 0.9336 - val_loss: 4.2469 - val_categorical_accuracy: 0.2600
# Epoch 14/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1909 - categorical_accuracy: 0.9427
# Epoch 00014: val_loss did not improve from 1.56328
# 23/23 [==============================] - 56s 2s/step - loss: 0.1909 - categorical_accuracy: 0.9427 - val_loss: 4.1006 - val_categorical_accuracy: 0.2700
# Epoch 15/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1625 - categorical_accuracy: 0.9548
# Epoch 00015: val_loss did not improve from 1.56328
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 23/23 [==============================] - 56s 2s/step - loss: 0.1625 - categorical_accuracy: 0.9548 - val_loss: 4.0505 - val_categorical_accuracy: 0.2700
# Epoch 16/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1835 - categorical_accuracy: 0.9442
# Epoch 00016: val_loss did not improve from 1.56328
# 23/23 [==============================] - 56s 2s/step - loss: 0.1835 - categorical_accuracy: 0.9442 - val_loss: 3.7224 - val_categorical_accuracy: 0.2700
# Epoch 17/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1981 - categorical_accuracy: 0.9397
# Epoch 00017: val_loss did not improve from 1.56328
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 23/23 [==============================] - 55s 2s/step - loss: 0.1981 - categorical_accuracy: 0.9397 - val_loss: 3.2482 - val_categorical_accuracy: 0.3000
# Epoch 18/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1672 - categorical_accuracy: 0.9563
# Epoch 00018: val_loss did not improve from 1.56328
# 23/23 [==============================] - 56s 2s/step - loss: 0.1672 - categorical_accuracy: 0.9563 - val_loss: 2.8090 - val_categorical_accuracy: 0.3200
# Epoch 19/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1690 - categorical_accuracy: 0.9623
# Epoch 00019: val_loss did not improve from 1.56328
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 23/23 [==============================] - 57s 2s/step - loss: 0.1690 - categorical_accuracy: 0.9623 - val_loss: 2.5716 - val_categorical_accuracy: 0.3100
# Epoch 20/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1913 - categorical_accuracy: 0.9457
# Epoch 00020: val_loss did not improve from 1.56328
# 23/23 [==============================] - 56s 2s/step - loss: 0.1913 - categorical_accuracy: 0.9457 - val_loss: 2.1403 - val_categorical_accuracy: 0.3600
# Epoch 21/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1925 - categorical_accuracy: 0.9382
# Epoch 00021: val_loss did not improve from 1.56328
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 23/23 [==============================] - 54s 2s/step - loss: 0.1925 - categorical_accuracy: 0.9382 - val_loss: 1.6015 - val_categorical_accuracy: 0.5000
# Epoch 22/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1886 - categorical_accuracy: 0.9427
# Epoch 00022: val_loss improved from 1.56328 to 1.39330, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 57s 2s/step - loss: 0.1886 - categorical_accuracy: 0.9427 - val_loss: 1.3933 - val_categorical_accuracy: 0.5200
# Epoch 23/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1762 - categorical_accuracy: 0.9517
# Epoch 00023: val_loss improved from 1.39330 to 1.18877, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 56s 2s/step - loss: 0.1762 - categorical_accuracy: 0.9517 - val_loss: 1.1888 - val_categorical_accuracy: 0.6100
# Epoch 24/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1594 - categorical_accuracy: 0.9668
# Epoch 00024: val_loss improved from 1.18877 to 0.91997, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 56s 2s/step - loss: 0.1594 - categorical_accuracy: 0.9668 - val_loss: 0.9200 - val_categorical_accuracy: 0.6700
# Epoch 25/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1617 - categorical_accuracy: 0.9638
# Epoch 00025: val_loss improved from 0.91997 to 0.85659, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 55s 2s/step - loss: 0.1617 - categorical_accuracy: 0.9638 - val_loss: 0.8566 - val_categorical_accuracy: 0.6400
# Epoch 26/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1637 - categorical_accuracy: 0.9563
# Epoch 00026: val_loss improved from 0.85659 to 0.70265, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 57s 2s/step - loss: 0.1637 - categorical_accuracy: 0.9563 - val_loss: 0.7026 - val_categorical_accuracy: 0.7000
# Epoch 27/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1655 - categorical_accuracy: 0.9593
# Epoch 00027: val_loss improved from 0.70265 to 0.48583, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 56s 2s/step - loss: 0.1655 - categorical_accuracy: 0.9593 - val_loss: 0.4858 - val_categorical_accuracy: 0.7500
# Epoch 28/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1847 - categorical_accuracy: 0.9502
# Epoch 00028: val_loss improved from 0.48583 to 0.44119, saving model to model_init_2021-08-0502_56_20.627047/final_model.h5
# 23/23 [==============================] - 56s 2s/step - loss: 0.1847 - categorical_accuracy: 0.9502 - val_loss: 0.4412 - val_categorical_accuracy: 0.8100
# Epoch 29/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1975 - categorical_accuracy: 0.9442
# Epoch 00029: val_loss did not improve from 0.44119
# 23/23 [==============================] - 55s 2s/step - loss: 0.1975 - categorical_accuracy: 0.9442 - val_loss: 0.5765 - val_categorical_accuracy: 0.7700
# Epoch 30/30
# 23/23 [==============================] - ETA: 0s - loss: 0.1747 - categorical_accuracy: 0.9563
# Epoch 00030: val_loss did not improve from 0.44119
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 23/23 [==============================] - 56s 2s/step - loss: 0.1747 - categorical_accuracy: 0.9563 - val_loss: 0.4477 - val_categorical_accuracy: 0.8200

# %% [markdown]
# ### Observation:
#
# On increase the epochs to 30 we see the validtaion accuracy increase and the issue of over fitting is resolved when compared to Conv3D_model1.

# %% [markdown]
# ## LETS USE KERNEL REGULARISER ON PREVIOUS CONV3D MODEL

# %% [markdown]
# ### Model 5 - Conv3D

# %%
Conv3D_model3 = Sequential()

Conv3D_model3.add(Conv3D(16, filtersize, padding='same', input_shape = input_shape))
Conv3D_model3.add(Activation('relu'))
Conv3D_model3.add(BatchNormalization())
Conv3D_model3.add(MaxPooling3D(pool_size=(2, 2, 2)))

Conv3D_model3.add(Conv3D(32, filtersize, padding='same'))
Conv3D_model3.add(Activation('relu'))
Conv3D_model3.add(BatchNormalization())
Conv3D_model3.add(MaxPooling3D(pool_size=(2, 2, 2)))

Conv3D_model3.add(Conv3D(64, filtersize, padding='same'))
Conv3D_model3.add(Activation('relu'))
Conv3D_model3.add(BatchNormalization())
Conv3D_model3.add(MaxPooling3D(pool_size=(2, 2, 2)))

Conv3D_model3.add(Conv3D(128, filtersize, padding='same'))
Conv3D_model3.add(Activation('relu'))
Conv3D_model3.add(BatchNormalization())
Conv3D_model3.add(MaxPooling3D(pool_size=(2, 2, 2)))

Conv3D_model3.add(Flatten())
Conv3D_model3.add(Dense(128,activation='relu', kernel_regularizer=l2(0.01)))
Conv3D_model3.add(BatchNormalization())
Conv3D_model3.add(Dropout(dropout))

Conv3D_model3.add(Dense(64,activation='relu'))
Conv3D_model3.add(BatchNormalization())
Conv3D_model3.add(Dropout(dropout))

Conv3D_model3.add(Dense(nb_classes, activation='softmax'))

Conv3D_model3.summary()
train_model(Conv3D_model3, batch_size , num_epochs, train_generator, val_generator, None)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 30, 120, 120, 16)  1312
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 15, 60, 60, 32)    13856
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 60, 60, 32)    0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 60, 60, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 7, 30, 30, 64)     55360
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 3, 15, 15, 128)    221312
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               802944
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,105,093
# Trainable params: 1,104,229
# Non-trainable params: 864
# _________________________________________________________________
# batch_size :30
# # of epoch :30
# Epoch 1/30
# 23/23 [==============================] - 64s 3s/step - loss: 3.9460 - categorical_accuracy: 0.4736 - val_loss: 4.5490 - val_categorical_accuracy: 0.1600
# Epoch 2/30
# 23/23 [==============================] - 59s 3s/step - loss: 3.1720 - categorical_accuracy: 0.6893 - val_loss: 7.7684 - val_categorical_accuracy: 0.1600
# Epoch 3/30
# 23/23 [==============================] - ETA: 0s - loss: 2.8789 - categorical_accuracy: 0.7029
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 [==============================] - 60s 3s/step - loss: 2.8789 - categorical_accuracy: 0.7029 - val_loss: 7.1265 - val_categorical_accuracy: 0.2400
# Epoch 4/30
# 23/23 [==============================] - 60s 3s/step - loss: 2.4370 - categorical_accuracy: 0.8220 - val_loss: 7.1395 - val_categorical_accuracy: 0.2400
# Epoch 5/30
# 23/23 [==============================] - ETA: 0s - loss: 2.3922 - categorical_accuracy: 0.7738
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 [==============================] - 60s 3s/step - loss: 2.3922 - categorical_accuracy: 0.7738 - val_loss: 7.4831 - val_categorical_accuracy: 0.1800
# Epoch 6/30
# 23/23 [==============================] - 58s 3s/step - loss: 2.1758 - categorical_accuracy: 0.8326 - val_loss: 6.7530 - val_categorical_accuracy: 0.2100
# Epoch 7/30
# 23/23 [==============================] - ETA: 0s - loss: 2.0130 - categorical_accuracy: 0.8929
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 [==============================] - 60s 3s/step - loss: 2.0130 - categorical_accuracy: 0.8929 - val_loss: 6.7672 - val_categorical_accuracy: 0.2100
# Epoch 8/30
# 23/23 [==============================] - 60s 3s/step - loss: 1.9229 - categorical_accuracy: 0.9050 - val_loss: 6.0706 - val_categorical_accuracy: 0.2500
# Epoch 9/30
# 23/23 [==============================] - ETA: 0s - loss: 1.8900 - categorical_accuracy: 0.8989
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 23/23 [==============================] - 60s 3s/step - loss: 1.8900 - categorical_accuracy: 0.8989 - val_loss: 6.7915 - val_categorical_accuracy: 0.1900
# Epoch 10/30
# 23/23 [==============================] - 58s 3s/step - loss: 1.8478 - categorical_accuracy: 0.9170 - val_loss: 6.0916 - val_categorical_accuracy: 0.2300
# Epoch 11/30
# 23/23 [==============================] - ETA: 0s - loss: 1.7957 - categorical_accuracy: 0.9321
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 23/23 [==============================] -
# %% [markdown]
# ### Observation:
#
# As the difference between accuracy of Conv3D_model2 is around 12% lets add kernel_regularizer. We can see improvement in both train and validation accuracy has imporved when compared to Conv3D_model2.

# %% [markdown]
# ## LETS IMPLEMENT TRANSFER LEARNING USING MOBILENET

# %% [markdown]
# ## Model 6 - MobileNet + LSTM

# %%
mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

modlelstm = Sequential()
modlelstm.add(TimeDistributed(mobilenet_transfer,input_shape=(input_shape)))

modlelstm.add(TimeDistributed(BatchNormalization()))
modlelstm.add(TimeDistributed(MaxPooling2D(pool_size=(2,2))))
modlelstm.add(TimeDistributed(Dropout(0.50)))
modlelstm.add(TimeDistributed(Flatten()))

modlelstm.add(LSTM(128))
modlelstm.add(Dropout(0.25))
modlelstm.add(Dense(128))
modlelstm.add(Activation('relu'))

modlelstm.add(Dense(5))
modlelstm.add(Activation('softmax'))
modlelstm.summary()

train_model(modlelstm, batch_size, num_epochs, train_generator, val_generator, None)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 30, 3, 3, 1024)    3228864
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 30, 3, 3, 1024)    4096
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 30, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 30, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 30, 1024)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               590336
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# _________________________________________________________________
# activation_1 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 3,840,453
# Trainable params: 3,816,517
# Non-trainable params: 23,936
# _________________________________________________________________
# batch_size :30
# # of epoch :30
# Source path =  /datasets/Project_data/train ; batch size = 30
# Epoch 1/30
# 23/23 [==============================] - ETA: 0s - loss: 1.6513 - categorical_accuracy: 0.2142Source path =  /datasets/Project_data/val ; batch size = 30
# 23/23 [==============================] - 77s 3s/step - loss: 1.6513 - categorical_accuracy: 0.2142 - val_loss: 1.5947 - val_categorical_accuracy: 0.3000
# Epoch 2/30
# 23/23 [==============================] - 71s 3s/step - loss: 1.4434 - categorical_accuracy: 0.4072 - val_loss: 1.4642 - val_categorical_accuracy: 0.4300
# Epoch 3/30
# 23/23 [==============================] - 71s 3s/step - loss: 1.2783 - categorical_accuracy: 0.5128 - val_loss: 1.2080 - val_categorical_accuracy: 0.6700
# Epoch 4/30
# 23/23 [==============================] - 70s 3s/step - loss: 1.0551 - categorical_accuracy: 0.6199 - val_loss: 1.5019 - val_categorical_accuracy: 0.2800
# Epoch 5/30
# 23/23 [==============================] - ETA: 0s - loss: 0.8344 - categorical_accuracy: 0.6787
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 [==============================] - 71s 3s/step - loss: 0.8344 - categorical_accuracy: 0.6787 - val_loss: 1.3975 - val_categorical_accuracy: 0.4200
# Epoch 6/30
# 23/23 [==============================] - 72s 3s/step - loss: 0.6356 - categorical_accuracy: 0.7813 - val_loss: 1.0971 - val_categorical_accuracy: 0.5200
# Epoch 7/30
# 23/23 [==============================] - 72s 3s/step - loss: 0.4447 - categorical_accuracy: 0.8612 - val_loss: 0.3360 - val_categorical_accuracy: 0.8700
# Epoch 8/30
# 23/23 [==============================] - 72s 3s/step - loss: 0.3392 - categorical_accuracy: 0.9201 - val_loss: 0.4469 - val_categorical_accuracy: 0.8500
# Epoch 9/30
# 23/23 [==============================] - 74s 3s/step - loss: 0.2237 - categorical_accuracy: 0.9593 - val_loss: 0.3167 - val_categorical_accuracy: 0.8800
# Epoch 10/30
# 23/23 [==============================] - 75s 3s/step - loss: 0.2178 - categorical_accuracy: 0.9548 - val_loss: 0.2106 - val_categorical_accuracy: 0.9300
# Epoch 11/30
# 23/23 [==============================] - 76s 3s/step - loss: 0.1215 - categorical_accuracy: 0.9774 - val_loss: 0.3252 - val_categorical_accuracy: 0.9000
# Epoch 12/30
# 23/23 [==============================] - ETA: 0s - loss: 0.
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 23/23 [==============================] - 74s 3s/step - loss: 0.0330 - categorical_accuracy: 0.9970 - val_loss: 0.1862 - val_categorical_accuracy: 0.9600
# Epoch 26/30
# 23/23 [==============================] - 75s 3s/step - loss: 0.0367 - categorical_accuracy: 0.9985 - val_loss: 0.2397 - val_categorical_accuracy: 0.9500
# Epoch 27/30
# 23/23 [==============================] - 74s 3s/step - loss: 0.0371 - categorical_accuracy: 0.9970 - val_loss: 0.0547 - val_categorical_accuracy: 0.9900
# Epoch 28/30
# 23/23 [==============================] - 72s 3s/step - loss: 0.0459 - categorical_accuracy: 0.9955 - val_loss: 0.1760 - val_categorical_accuracy: 0.9600
# Epoch 29/30
# 23/23 [==============================] - ETA: 0s - loss: 0.0357 - categorical_accuracy: 1.0000
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 23/23 [==============================] - 74s 3s/step - loss: 0.0357 - categorical_accuracy: 1.0000 - val_loss: 0.1810 - val_categorical_accuracy: 0.9600
# Epoch 30/30
# 23/23 [==============================] - 75s 3s/step - loss: 0.0334 - categorical_accuracy: 0.9985 - val_loss: 0.1912 - val_categorical_accuracy: 0.9600

# %% [markdown]
# ### Observation:
#
# As Validation accuracy of Conv3D_model3 is not above 90% lets impliment transfer learning. On doing so we see a good increase in Validation Accuracy and it crosses above 95%. This truns out to be a best model so far compared to all the previous models.

# %% [markdown]
# ## Model 7 - MobileNet + GRU

# %%
mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

modlegru = Sequential()
modlegru.add(TimeDistributed(mobilenet_transfer,input_shape=(input_shape)))


modlegru.add(TimeDistributed(BatchNormalization()))
modlegru.add(TimeDistributed(MaxPooling2D(pool_size=(2,2))))
modlegru.add(TimeDistributed(Dropout(0.50)))
modlegru.add(TimeDistributed(Flatten()))

modlegru.add(GRU(128))
modlegru.add(Dropout(0.25))
modlegru.add(Dense(128))
modlegru.add(Activation('relu'))

modlegru.add(Dense(5))
modlegru.add(Activation('softmax'))
modlegru.summary()
train_model(modlegru, batch_size, num_epochs, train_generator, val_generator, None, True)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 30, 3, 3, 1024)    3228864
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 30, 3, 3, 1024)    4096
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 30, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 30, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 30, 1024)          0
# _________________________________________________________________
# gru (GRU)                    (None, 128)               443136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# _________________________________________________________________
# activation_1 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# batch_size :30
# # of epoch :30
# Source path =  Project_data/train ; batch size = 30
# Epoch 1/30
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-39-3928b2b6602a> in <module>
#      18 modlegru.add(Activation('softmax'))
#      19 modlegru.summary()
# ---> 20 train_model(modlegru, batch_size, num_epochs, train_generator, val_generator, None, True)
#
# <ipython-input-38-fd5d3d724b43> in train_model(model, batch_size, num_epochs, train_generator, val_generator, optimizer, checkpoint_flag)
#      54     # fit the model - This will start training the model and with the help of the checkpoints,
#      55     # you'll be able to save the model at the end of each epoch.
# ---> 56     model_history = model.fit(train_generator, steps_per_epoch = steps_per_epoch, epochs = num_epochs, verbose = 1,
#      57                 callbacks = callbacks_list, validation_data = val_generator,
#      58                 validation_steps = validation_steps, class_weight = None, workers = 1, initial_epoch = 0)
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[57600,61,61] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node sequential/time_distributed/conv_pad_2/Pad (defined at <ipython-input-38-fd5d3d724b43>:56) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_17152]
#
# Function call stack:
# train_function

# %% [markdown]
# ### Observation:
#
# Using the above model and on  switching from LSTM to GRU, we see the model behaves almost the same and produces similar accuracy results/

# %%
end = time.time()
print(end - start)
# Out:
# 9177.968208312988
